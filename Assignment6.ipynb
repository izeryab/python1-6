# %%
import random

# %%
import sys

# %%
def mimic_dict(filename):
  """Returns mimic dict mapping each word to list of words which follow it."""
  # LAB(begin solution)
  mimic_dict = {}
  f = open(filename, 'r')
  text = f.read()
  f.close()
  words = text.split()
  prev = ''
  for word in words:
    if not prev in mimic_dict:
      mimic_dict[prev] = [word]
    else:
      mimic_dict[prev].append(word)
    # Could write as: mimic_dict[prev] = mimic_dict.get(prev, []) + [word]
    # It's one line, but not totally satisfying.
    prev = word
  return mimic_dict

# %%
mimic_dict('alice.txt')
# Out:
# {'': ["Alice's"],
#  "Alice's": ['Adventures',
#   'first',
#   'elbow',
#   'head.',
#   'side',
#   'shoulder,',
#   'shoulder',
#   'great',
#   'Evidence'],
#  'Adventures': ['in', 'of'],
#  'in': ['Wonderland',
#   'it,',
#   'her',
#   'that;',
#   'time',
#   'the',
#   'her',
#   'the',
#   'the',
#   'a',
#   'hand',
#   'a',
#   'sight,',
#   'time',
#   'a',
#   'the',
#   'waiting',
#   'large',
#   'a',
#   'fact,',
#   'crying',
#   'a',
#   'it',
#   'currants.',
#   'the',
#   'fact',
#   'this',
#   'the',
#   'one',
#   'the',
#   'a',
#   'a',
#   'the',
#   'the',
#   'such',
#   'ringlets',
#   'With',
#   'that',
#   'time',
#   'existence;',
#   'another',
#   'salt',
#   'that',
#   'her',
#   'the',
#   'the',
#   'the',
#   'my',
#   'the',
#   'like',
#   "trying.'",
#   'her',
#   'her',
#   'a',
#   'a',
#   'the',
#   'a',
#   'a',
#   'the',
#   'a',
#   'a',
#   'the',
#   'a',
#   'an',
#   'a',
#   'which',
#   'the',
#   'silence.',
#   'a',
#   'despair',
#   'her',
#   'your',
#   'a',
#   'a',
#   'the',
#   'reply.',
#   'chorus,',
#   'particular.',
#   'a',
#   "bed!'",
#   'a',
#   'the',
#   'the',
#   'a',
#   'a',
#   'the',
#   'an',
#   'the',
#   'without',
#   'great',
#   'a',
#   'the',
#   'the',
#   'another',
#   'the',
#   'a',
#   'here?',
#   'at',
#   'the',
#   'the',
#   'the',
#   'here',
#   "Bill's",
#   'the',
#   'at',
#   'the',
#   'my',
#   'the',
#   'a',
#   'the',
#   'a',
#   'a',
#   'which',
#   'spite',
#   'its',
#   'the',
#   'silence:',
#   'a',
#   'a',
#   'a',
#   'a',
#   'at',
#   'her',
#   'a',
#   "time,'",
#   'the',
#   'another',
#   'a',
#   'another',
#   'any',
#   'curving',
#   'among',
#   'a',
#   'a',
#   'saying',
#   'the',
#   'a',
#   'my',
#   'a',
#   'her',
#   'bringing',
#   'a',
#   'it',
#   'livery',
#   'livery:',
#   'livery,',
#   'a',
#   'the',
#   "knocking,'",
#   'your',
#   'the',
#   'a',
#   'at',
#   'talking',
#   'the',
#   'that',
#   'the',
#   'the',
#   'another',
#   'fact,',
#   'an',
#   'a',
#   'all',
#   'a',
#   'reply',
#   'silence.',
#   'some',
#   'THAT',
#   'a',
#   'the',
#   'which',
#   "March.'",
#   'my',
#   'sight',
#   'front',
#   'a',
#   'an',
#   'his',
#   'as',
#   'with',
#   'it,',
#   'asking',
#   'the',
#   'a',
#   'a',
#   'the',
#   'its',
#   'a',
#   'a',
#   'a',
#   'questions',
#   'an',
#   'great',
#   'all',
#   'at',
#   'she',
#   'the',
#   'her',
#   'the',
#   'a',
#   'a',
#   'by',
#   'hand,',
#   'couples:',
#   'a',
#   'reply.',
#   'a',
#   'a',
#   'reply.',
#   'a',
#   'a',
#   'a',
#   'all',
#   'a',
#   'her',
#   'managing',
#   'getting',
#   'her',
#   'the',
#   'the',
#   'a',
#   'a',
#   'a',
#   'the',
#   'sight,',
#   'rather',
#   'particular;',
#   'a',
#   'some',
#   'the',
#   'such',
#   'search',
#   'a',
#   'a',
#   'less',
#   "prison,'",
#   'such',
#   'the',
#   'a',
#   'my',
#   'a',
#   "things!'",
#   'a',
#   'the',
#   'front',
#   'a',
#   'about',
#   'a',
#   'the',
#   'custody',
#   'a',
#   'the',
#   'all',
#   'the',
#   'the',
#   'a',
#   'the',
#   'these',
#   'the',
#   'a',
#   'surprise.',
#   "Coils.'",
#   'his',
#   'their',
#   'a',
#   'a',
#   'his',
#   'the',
#   'same',
#   'the',
#   'their',
#   'the',
#   'their',
#   'their',
#   'a',
#   'a',
#   'a',
#   'a',
#   'an',
#   'an',
#   'contemptuous',
#   'her',
#   'a',
#   "dancing.'",
#   'a',
#   'a',
#   'a',
#   'a',
#   'the',
#   'chains,',
#   'one',
#   'the',
#   'a',
#   'books,',
#   'reply,',
#   'a',
#   'the',
#   'before',
#   'with',
#   'one',
#   'the',
#   'his',
#   'that',
#   'the',
#   'a',
#   'a',
#   'the',
#   'her',
#   'a',
#   'a',
#   'confusion,',
#   'an',
#   'the',
#   'the',
#   'such',
#   'a',
#   'her',
#   'a',
#   'their',
#   'her',
#   'head',
#   'a',
#   'the',
#   'a',
#   'an',
#   'his',
#   'the',
#   'a',
#   'a',
#   "it?'",
#   'the',
#   'this',
#   'the',
#   "it.'",
#   "it,'",
#   "it,'",
#   'them,',
#   'an',
#   'the',
#   'to',
#   'Wonderland,',
#   'the',
#   'the',
#   'the',
#   'all'],
#  'Wonderland': ["ALICE'S", 'of'],
#  "ALICE'S": ['ADVENTURES', 'RIGHT', 'LOVE).'],
#  'ADVENTURES': ['IN'],
#  'IN': ['WONDERLAND', 'the'],
#  'WONDERLAND': ['Lewis'],
#  'Lewis': ['Carroll'],
#  'Carroll': ['THE'],
#  'THE': ['MILLENNIUM',
#   'FENDER,',
#   'LITTLE',
#   'KING',
#   'BOOTS',
#   'VOICE',
#   'SLUGGARD,"\'',
#   "COURT.'",
#   'END'],
#  'MILLENNIUM': ['FULCRUM'],
#  'FULCRUM': ['EDITION'],
#  'EDITION': ['3.0'],
#  '3.0': ['CHAPTER'],
#  'CHAPTER': ['I',
#   'II',
#   'III',
#   'IV',
#   'V',
#   'VI',
#   'VII',
#   'VIII',
#   'IX',
#   'X',
#   'XI',
#   'XII'],
#  'I': ['Down',
#   'shall',
#   'shall',
#   "wouldn't",
#   'fell',
#   "think--'",
#   'wonder',
#   'shall',
#   "think--'",
#   'shall',
#   'shall',
#   'should',
#   'wish',
#   "wonder?'",
#   'wish',
#   'could',
#   'think',
#   'could,',
#   'only',
#   'wonder',
#   'should',
#   'can',
#   'can',
#   "don't",
#   'wonder',
#   'shall',
#   'must',
#   'want',
#   'tell',
#   'wonder',
#   'the',
#   'got',
#   'almost',
#   'can',
#   "can't",
#   'know',
#   'know',
#   'used',
#   'shall',
#   'must',
#   'shall',
#   'shall',
#   'then?',
#   'like',
#   'am',
#   'have',
#   'never',
#   'declare',
#   'can',
#   "hadn't",
#   'suppose,',
#   'should',
#   'am',
#   'beg',
#   'wish',
#   'could',
#   'think',
#   'beg',
#   'would',
#   'should',
#   'hate',
#   'know.',
#   'find',
#   "don't",
#   'was',
#   'will',
#   'will',
#   "think?'",
#   'had',
#   'know',
#   "do!'",
#   'might',
#   'wish',
#   "hadn't",
#   'wonder',
#   'shall',
#   'have',
#   "wonder?'",
#   'am!',
#   'can',
#   'suppose',
#   "don't",
#   'eat',
#   'do',
#   "shan't",
#   "can't",
#   "hadn't",
#   'can',
#   'almost',
#   "hadn't",
#   'do',
#   'used',
#   'fancied',
#   'am',
#   'grow',
#   'NEVER',
#   'am',
#   "shouldn't",
#   "don't",
#   'tell',
#   'only',
#   "don't",
#   "hadn't",
#   "fancy--Who's",
#   "shan't!",
#   "won't,",
#   "wouldn't",
#   'THINK',
#   'can',
#   'hardly',
#   'know',
#   'goes',
#   'eat',
#   "suppose.'",
#   'think',
#   'suppose',
#   'ought',
#   'know',
#   'WAS',
#   'got',
#   'think',
#   'must',
#   "can't",
#   "can't",
#   'should',
#   'know',
#   'am,',
#   'used--and',
#   "don't",
#   'have',
#   'do',
#   'mentioned',
#   'can',
#   'should',
#   "can't",
#   'say',
#   'must',
#   "haven't",
#   'was',
#   'should',
#   'tell',
#   'suppose',
#   'can',
#   'know',
#   'was,',
#   "shouldn't",
#   "don't",
#   "wonder?'",
#   'should',
#   'to',
#   'could',
#   'to',
#   'to',
#   'to',
#   "didn't",
#   'THINK;',
#   'beat',
#   "don't",
#   'to',
#   'get',
#   "think.'",
#   'ought',
#   'get',
#   "don't",
#   'growl',
#   "haven't",
#   'wish',
#   'ever',
#   'almost',
#   'suppose',
#   'can',
#   'mean',
#   "say--that's",
#   'eat"',
#   'see"!\'',
#   'get"',
#   'like"!\'',
#   'sleep"',
#   'breathe"!\'',
#   'was',
#   'give',
#   "do,'",
#   'know',
#   'have',
#   'learn',
#   'had',
#   'wonder',
#   'ask!',
#   "suppose?'",
#   'vote',
#   "don't",
#   "can't",
#   'dare',
#   "don't",
#   'should',
#   'ever',
#   'think',
#   'may',
#   "needn't",
#   "know?'",
#   "didn't,'",
#   'said',
#   'shall',
#   'should',
#   "don't",
#   'wish',
#   'am',
#   'only',
#   "can't",
#   'shall',
#   "don't",
#   'try',
#   "THINK,'",
#   "know!'",
#   'should',
#   'had',
#   "can't",
#   'could',
#   "chose,'",
#   'give',
#   'must',
#   'have',
#   "didn't!'",
#   "suppose?'",
#   "can't",
#   'do',
#   'never',
#   "believe.'",
#   'should',
#   "say,'",
#   'was',
#   'heard',
#   'must',
#   'used',
#   'was',
#   'never',
#   'ever',
#   'think',
#   "hadn't",
#   'was',
#   'think',
#   'grow',
#   "hadn't",
#   "can't",
#   'will',
#   'never',
#   'must,',
#   "must,'",
#   'BEG',
#   "meant,'",
#   "shan't",
#   'did:',
#   'begin,',
#   'could',
#   'had',
#   'gave',
#   'or',
#   "don't",
#   'COULD',
#   'look',
#   "think?'"],
#  'Down': ['the'],
#  'the': ['Rabbit-Hole',
#   'bank,',
#   'book',
#   'use',
#   'hot',
#   'pleasure',
#   'trouble',
#   'daisies,',
#   'way',
#   'Rabbit',
#   'time',
#   'Rabbit',
#   'field',
#   'hedge.',
#   'world',
#   'well',
#   'sides',
#   'well,',
#   'shelves',
#   'jar',
#   'cupboards',
#   'top',
#   "house!'",
#   'fall',
#   'centre',
#   'earth.',
#   'schoolroom,',
#   'right',
#   'earth!',
#   'people',
#   'right',
#   'name',
#   'country',
#   'air!',
#   'cat.)',
#   'air,',
#   'truth:',
#   'fall',
#   'White',
#   'wind,',
#   'corner,',
#   'Rabbit',
#   'roof.',
#   'hall,',
#   'way',
#   'other,',
#   'middle,',
#   'doors',
#   'hall;',
#   'locks',
#   'key',
#   'second',
#   'little',
#   'lock,',
#   'door',
#   'passage',
#   'loveliest',
#   'doorway;',
#   'little',
#   'table,',
#   'neck',
#   'bottle',
#   'words',
#   'wise',
#   'simple',
#   'thought',
#   'right',
#   'little',
#   'flame',
#   'candle',
#   'garden',
#   'door,',
#   'little',
#   'table',
#   'glass,',
#   'legs',
#   'table,',
#   'poor',
#   'table:',
#   'words',
#   'key;',
#   'door;',
#   'garden,',
#   'top',
#   'same',
#   'way',
#   'common',
#   'cake.',
#   'moment',
#   'largest',
#   'best',
#   'way',
#   "carrier,'",
#   'directions',
#   'roof',
#   'hall:',
#   'little',
#   'garden',
#   'garden',
#   'same,',
#   'hall.',
#   'distance,',
#   'White',
#   'other:',
#   'Duchess,',
#   'Duchess!',
#   'Rabbit',
#   'white',
#   'fan,',
#   'darkness',
#   'fan',
#   'hall',
#   'time',
#   'night?',
#   'same',
#   'same,',
#   'next',
#   'world',
#   'great',
#   'children',
#   'same',
#   'things',
#   'Multiplication',
#   'capital',
#   'capital',
#   'little--"\'',
#   'words',
#   'same',
#   'little',
#   'waters',
#   'Nile',
#   'right',
#   "Rabbit's",
#   'table',
#   'cause',
#   'fan',
#   'sudden',
#   "garden!'",
#   'little',
#   'little',
#   'little',
#   'glass',
#   'poor',
#   'sea,',
#   'seaside',
#   'general',
#   'English',
#   'sea,',
#   'sand',
#   'pool',
#   'pool',
#   'way',
#   'right',
#   "Conqueror.'",
#   'first',
#   'water,',
#   'poor',
#   'Mouse,',
#   'pool,',
#   'fire,',
#   'Mouse',
#   'Mouse,',
#   'end',
#   'name',
#   'subject',
#   'rats',
#   'Mouse',
#   'pool',
#   'Mouse',
#   'shore,',
#   'pool',
#   'birds',
#   'way,',
#   'whole',
#   'shore.',
#   'bank--the',
#   'animals',
#   'Lory,',
#   'Lory',
#   'Mouse,',
#   'Mouse',
#   'middle.',
#   'Mouse',
#   'driest',
#   'Conqueror,',
#   'pope,',
#   'English,',
#   'earls',
#   'Lory,',
#   'Mouse,',
#   'Lory',
#   'Mouse.',
#   'earls',
#   'patriotic',
#   'Duck.',
#   'Mouse',
#   'Duck:',
#   'archbishop',
#   'crown.',
#   'insolence',
#   'Dodo',
#   'meeting',
#   'immediate',
#   'Eaglet.',
#   'meaning',
#   'Eaglet',
#   'other',
#   'Dodo',
#   'best',
#   'Dodo',
#   'Dodo,',
#   'thing',
#   'Dodo',
#   'party',
#   'course,',
#   'race',
#   'Dodo',
#   'Dodo',
#   'pictures',
#   'rest',
#   'Dodo',
#   "prizes?'",
#   'Dodo,',
#   'whole',
#   'salt',
#   'Mouse.',
#   'Dodo',
#   'Dodo.',
#   'Dodo',
#   'thimble,',
#   'whole',
#   'thimble,',
#   'comfits:',
#   'large',
#   'small',
#   'back.',
#   'Mouse',
#   'Mouse,',
#   "Mouse's",
#   'Mouse',
#   'tale',
#   'house,',
#   'mouse',
#   'cur,',
#   'whole',
#   'Mouse',
#   'fifth',
#   'Mouse,',
#   "sort,'",
#   'Mouse,',
#   'others',
#   'Mouse',
#   'Lory,',
#   'opportunity',
#   'young',
#   'patience',
#   "question?'",
#   'Lory.',
#   'birds!',
#   'party.',
#   'birds',
#   'night-air',
#   'best',
#   'world!',
#   'distance,',
#   'Mouse',
#   'White',
#   'fan',
#   'pair',
#   'pool,',
#   'great',
#   'glass',
#   'little',
#   'Rabbit',
#   'direction',
#   'mistake',
#   'door',
#   'name',
#   'real',
#   'house',
#   'fan',
#   'sort',
#   'mouse',
#   'house',
#   'window,',
#   'fan',
#   'gloves,',
#   'room,',
#   'looking-',
#   'words',
#   'bottle,',
#   'ceiling,',
#   'bottle,',
#   'door--I',
#   'floor:',
#   'effect',
#   'door,',
#   'other',
#   'window,',
#   'chimney,',
#   'little',
#   'room',
#   'middle',
#   'other,',
#   'voice.',
#   'stairs.',
#   'Rabbit',
#   'house,',
#   'Rabbit,',
#   'Rabbit',
#   'door,',
#   'door',
#   "window.'",
#   'Rabbit',
#   'window,',
#   'air.',
#   'sort.',
#   'Rabbit',
#   "window?'",
#   'whole',
#   'air.',
#   'window,',
#   'sound',
#   'words:',
#   'other',
#   'other--Bill!',
#   'roof',
#   'chimney?--Nay,',
#   'master',
#   "chimney!'",
#   'chimney,',
#   'chimney',
#   'chimney',
#   "Rabbit's",
#   "hedge!'",
#   'others.',
#   'house',
#   "Rabbit's",
#   'roof',
#   'Rabbit',
#   'next',
#   'window,',
#   'face.',
#   'pebbles',
#   'floor,',
#   'cakes,',
#   'door,',
#   'house,',
#   'middle,',
#   'moment',
#   'wood,',
#   'second',
#   'best',
#   'only',
#   'smallest',
#   'trees,',
#   'time',
#   'thought',
#   'puppy;',
#   'puppy',
#   'air',
#   'stick,',
#   'moment',
#   'other',
#   'puppy',
#   'stick,',
#   'thistle',
#   'puppy',
#   'stick,',
#   'while,',
#   "puppy's",
#   'distance.',
#   'leaves:',
#   'right',
#   'great',
#   'flowers',
#   'blades',
#   'right',
#   'circumstances.',
#   'same',
#   'top',
#   'edge',
#   'mushroom,',
#   'top',
#   'smallest',
#   'Caterpillar',
#   'hookah',
#   'Caterpillar.',
#   'Caterpillar',
#   'Caterpillar.',
#   'Caterpillar.',
#   'Caterpillar.',
#   'Caterpillar',
#   'beginning',
#   'conversation.',
#   "Caterpillar's",
#   'Caterpillar.',
#   'Caterpillar',
#   'Caterpillar',
#   'Caterpillar.',
#   'Caterpillar.',
#   'hookah',
#   'same',
#   'Caterpillar.',
#   'Caterpillar.',
#   'young',
#   'brain;',
#   'youth,',
#   'door--',
#   'reason',
#   'sage,',
#   'use',
#   'box--',
#   'youth,',
#   'goose,',
#   'bones',
#   'beak--',
#   'law,',
#   'muscular',
#   'rest',
#   'youth,',
#   'end',
#   'Caterpillar.',
#   'words',
#   'Caterpillar',
#   'first',
#   'Caterpillar.',
#   'Caterpillar.',
#   'Caterpillar',
#   'creatures',
#   'Caterpillar;',
#   'hookah',
#   'Caterpillar',
#   'hookah',
#   'mushroom,',
#   'grass,',
#   'other',
#   "mushroom,'",
#   'Caterpillar,',
#   'mushroom',
#   'two',
#   'edge',
#   'right-hand',
#   'effect:',
#   'next',
#   'other',
#   'lefthand',
#   'distant',
#   'leaves,',
#   'tops',
#   'trees',
#   'Pigeon.',
#   'Pigeon,',
#   'least',
#   'roots',
#   'Pigeon',
#   'Pigeon',
#   "eggs,'",
#   'Pigeon;',
#   'look-out',
#   'highest',
#   "wood,'",
#   'Pigeon,',
#   'sky!',
#   'Pigeon.',
#   'number',
#   'Pigeon',
#   'deepest',
#   'Pigeon;',
#   'Pigeon',
#   'opportunity',
#   'Pigeon',
#   'trees',
#   'branches,',
#   'pieces',
#   'other,',
#   'right',
#   'next',
#   'righthand',
#   'house',
#   'house,',
#   'wood--(she',
#   'door',
#   'wood',
#   'other,',
#   'Duchess.',
#   'Queen',
#   'same',
#   'order',
#   'words',
#   'Queen.',
#   'Duchess',
#   'wood',
#   'Fish-Footman',
#   'other',
#   'ground',
#   'door,',
#   'sky.',
#   'door,',
#   'Footman,',
#   'same',
#   'door',
#   'Footman',
#   'door',
#   'sky',
#   'time',
#   'top',
#   'Footman',
#   'door',
#   'house',
#   "Footman's",
#   'trees',
#   'Footman',
#   'same',
#   'Footman.',
#   'first',
#   'creatures',
#   'Footman,',
#   'door',
#   'other:',
#   'Duchess',
#   'middle,',
#   'cook',
#   'fire,',
#   'air.',
#   'Duchess',
#   'baby,',
#   'kitchen',
#   'cook,',
#   'hearth',
#   'Duchess,',
#   'last',
#   'baby,',
#   'Duchess;',
#   'Duchess;',
#   'tone',
#   'cook',
#   'cauldron',
#   'fire,',
#   'Duchess',
#   'baby',
#   'baby',
#   'blows',
#   'Duchess',
#   'day',
#   'earth',
#   'Duchess,',
#   'cook,',
#   'hint;',
#   'cook',
#   'soup,',
#   'Duchess;',
#   'end',
#   'cook',
#   'baby',
#   'Duchess',
#   'second',
#   'song,',
#   'baby',
#   'poor',
#   'words:--',
#   'Duchess',
#   'baby',
#   "Queen,'",
#   'room.',
#   'baby',
#   'first',
#   'proper',
#   'open',
#   'last',
#   'little',
#   'matter',
#   'look',
#   'thing',
#   'little',
#   'wood.',
#   'right',
#   'Cheshire',
#   'name:',
#   'Cat.',
#   'Cat.',
#   'Cat,',
#   'Cat',
#   'other',
#   'Cat:',
#   'Cat,',
#   'Cat,',
#   'Cat',
#   'Cat.',
#   'Queen',
#   'Cat,',
#   'place',
#   "baby?'",
#   'Cat.',
#   'Cat,',
#   'direction',
#   'March',
#   'most',
#   'Cat',
#   'Cat.',
#   'Cat;',
#   'end',
#   'tail,',
#   'grin,',
#   'rest',
#   'most',
#   'house',
#   'March',
#   'right',
#   'chimneys',
#   'roof',
#   'lefthand',
#   'Hatter',
#   'house,',
#   'March',
#   'Hatter',
#   'other',
#   "Dormouse,'",
#   'three',
#   'table.',
#   'March',
#   'table,',
#   'March',
#   'March',
#   'Hatter.',
#   'answer',
#   'March',
#   'March',
#   'same',
#   'same',
#   'Hatter.',
#   'same',
#   'March',
#   'same',
#   'Dormouse,',
#   'same',
#   'same',
#   'Hatter,',
#   'conversation',
#   'party',
#   'first',
#   'silence.',
#   'month',
#   'Hatter.',
#   "works!'",
#   'March',
#   'BEST',
#   'March',
#   'Hatter',
#   "bread-knife.'",
#   'watch',
#   'BEST',
#   'day',
#   'month,',
#   'Hatter.',
#   'same',
#   'case',
#   'Hatter.',
#   'Hatter,',
#   'riddle',
#   'Hatter',
#   "answer?'",
#   'slightest',
#   'Hatter.',
#   'March',
#   "time,'",
#   'Hatter,',
#   'Hatter',
#   'Hatter.',
#   'clock.',
#   'morning,',
#   'clock',
#   'March',
#   'Hatter:',
#   'way',
#   'March',
#   'great',
#   'Queen',
#   'song,',
#   'Hatter',
#   'world',
#   'sky.',
#   'Dormouse',
#   'first',
#   'Hatter,',
#   'Queen',
#   'time!',
#   'Hatter',
#   'reason',
#   'Hatter',
#   'things',
#   'Hatter:',
#   'things',
#   'beginning',
#   "subject,'",
#   'March',
#   'young',
#   'proposal.',
#   'Dormouse',
#   'March',
#   'Hatter,',
#   'Dormouse',
#   'bottom',
#   'Dormouse,',
#   'Dormouse;',
#   'bottom',
#   'March',
#   'Hatter:',
#   'Hatter',
#   'Dormouse,',
#   'bottom',
#   'Hatter',
#   'March',
#   'Dormouse',
#   'story',
#   'Dormouse',
#   'Dormouse,',
#   'Hatter:',
#   'Dormouse',
#   'March',
#   "Dormouse's",
#   'place',
#   'March',
#   'only',
#   'change:',
#   'March',
#   'milk-jug',
#   'Dormouse',
#   'treacle',
#   'Hatter;',
#   "well,'",
#   'Dormouse,',
#   'Dormouse;',
#   'Dormouse',
#   'Dormouse',
#   'March',
#   'Hatter,',
#   'moon,',
#   'Hatter.',
#   'Dormouse',
#   'others',
#   'least',
#   'last',
#   'Dormouse',
#   'teapot.',
#   'wood.',
#   'stupidest',
#   'trees',
#   'long',
#   'little',
#   'little',
#   'door',
#   'garden.',
#   'mushroom',
#   'little',
#   'beautiful',
#   'bright',
#   'cool',
#   'entrance',
#   'garden:',
#   'roses',
#   'blame',
#   'Queen',
#   'one',
#   'cook',
#   'unjust',
#   'others',
#   'fact',
#   'Queen',
#   'garden,',
#   'three',
#   'Queen.',
#   'three',
#   'corners:',
#   'ten',
#   'soldiers',
#   'royal',
#   'little',
#   'guests,',
#   'White',
#   'Knave',
#   "King's",
#   'three',
#   'use',
#   'procession',
#   'Queen',
#   'Knave',
#   'Queen,',
#   'Queen,',
#   'three',
#   'rosetree;',
#   'pattern',
#   'same',
#   'rest',
#   'pack,',
#   'Queen',
#   'Knave',
#   'Queen,',
#   'three',
#   'King,',
#   'Queen,',
#   'royal',
#   'Queen.',
#   'rose-tree,',
#   'Queen,',
#   'roses.',
#   'procession',
#   'soldiers',
#   'unfortunate',
#   'others.',
#   'Queen.',
#   'soldiers',
#   'Queen.',
#   'question',
#   'Queen,',
#   'procession,',
#   'White',
#   "Duchess?'",
#   'Rabbit',
#   'Rabbit',
#   "Queen's",
#   'Rabbit',
#   'Rabbit',
#   'Queen',
#   'Queen',
#   'game',
#   'balls',
#   'mallets',
#   'soldiers',
#   'arches.',
#   'hedgehog',
#   'hedgehog',
#   'act',
#   'way',
#   'hedgehog',
#   'doubled-up',
#   'ground,',
#   'conclusion',
#   'while,',
#   'hedgehogs;',
#   'Queen',
#   'Queen,',
#   'great',
#   'air:',
#   'Cheshire',
#   'Cat,',
#   'eyes',
#   'whole',
#   'game,',
#   'things',
#   'arch',
#   'other',
#   'ground--and',
#   "Queen's",
#   "Queen?'",
#   'Cat',
#   'Queen',
#   "game.'",
#   'King,',
#   "Cat's",
#   'look',
#   'King:',
#   'Cat',
#   'King,',
#   'King',
#   'Queen,',
#   'moment,',
#   'executioner',
#   'King',
#   'game',
#   "Queen's",
#   'distance,',
#   'players',
#   'look',
#   'game',
#   'other:',
#   'only',
#   'other',
#   'garden,',
#   'time',
#   'flamingo',
#   'fight',
#   'hedgehogs',
#   'arches',
#   "ground.'",
#   'Cheshire',
#   'executioner,',
#   'King,',
#   'Queen,',
#   'rest',
#   'question,',
#   'whole',
#   'Duchess:',
#   'Queen',
#   'executioner:',
#   'executioner',
#   'moment',
#   'time',
#   'Duchess,',
#   'King',
#   'executioner',
#   'rest',
#   'party',
#   'game.',
#   'Duchess,',
#   'pepper',
#   'kitchen.',
#   'Duchess',
#   'moral',
#   'Duchess.',
#   'Duchess',
#   'right',
#   'conversation',
#   'Duchess:',
#   'moral',
#   'world',
#   'same',
#   'Duchess,',
#   'moral',
#   'sense,',
#   'sounds',
#   'Duchess',
#   'temper',
#   "experiment?'",
#   'experiment',
#   'Duchess:',
#   'moral',
#   'Duchess:',
#   'Duchess,',
#   'moral',
#   'less',
#   'Duchess;',
#   'moral',
#   'Duchess',
#   'Duchess.',
#   'Duchess',
#   'Duchess,',
#   "m--'",
#   "Duchess's",
#   'middle',
#   'arm',
#   'Queen',
#   'Duchess',
#   'Queen,',
#   'ground',
#   "game,'",
#   'Queen',
#   'croquet-ground.',
#   "Queen's",
#   'shade:',
#   'moment',
#   'game,',
#   'Queen',
#   'time',
#   'Queen',
#   'other',
#   'soldiers,',
#   'end',
#   'players,',
#   'King,',
#   'Queen,',
#   'Queen',
#   'Mock',
#   'thing',
#   'Queen.',
#   'Queen,',
#   'King',
#   'company',
#   'number',
#   'Queen',
#   'sun.',
#   'picture.)',
#   'Queen,',
#   'Mock',
#   'Gryphon.',
#   'look',
#   'creature,',
#   'whole',
#   'Queen',
#   'Gryphon,',
#   "fun?'",
#   'Gryphon.',
#   'Mock',
#   'distance,',
#   'Gryphon,',
#   'Gryphon',
#   'same',
#   'Mock',
#   'Gryphon,',
#   'Mock',
#   'Mock',
#   'Gryphon,',
#   'constant',
#   'Mock',
#   'Mock',
#   'sea.',
#   'Mock',
#   'Gryphon;',
#   'earth.',
#   'Gryphon',
#   ...],
#  'Rabbit-Hole': ['Alice'],
#  'Alice': ['was',
#   '`without',
#   'think',
#   'started',
#   'after',
#   'had',
#   'to',
#   'had',
#   'soon',
#   'began',
#   'was',
#   'like',
#   'had',
#   'opened',
#   'had',
#   'was',
#   'ventured',
#   'to',
#   'to',
#   'had',
#   '(she',
#   'felt',
#   'took',
#   'had',
#   'hastily,',
#   'in',
#   'went',
#   'again,',
#   'went',
#   'in',
#   'thought),',
#   'led',
#   'to',
#   'would',
#   'kept',
#   'as',
#   'in',
#   'with',
#   'had',
#   'sadly.',
#   'thought',
#   'severely.',
#   'very',
#   'called',
#   'aloud,',
#   'replied',
#   'was',
#   'began',
#   'guessed',
#   'was',
#   'said',
#   'went',
#   'knew',
#   'heard',
#   'could',
#   'to',
#   'called',
#   'thought',
#   'heard',
#   'noticed',
#   'the',
#   'to',
#   'dodged',
#   'a',
#   'looked',
#   'looked',
#   'replied,',
#   'replied',
#   'felt',
#   'could',
#   'turned',
#   'thought',
#   'replied',
#   'folded',
#   'hastily',
#   'said',
#   'in',
#   'waited',
#   'to',
#   'remained',
#   'in',
#   'indignantly.',
#   'was',
#   'hastily;',
#   'crouched',
#   'noticed,',
#   'laughed',
#   'went',
#   'thought',
#   'again,',
#   'did',
#   'desperately:',
#   'said',
#   'quite',
#   'said',
#   'did',
#   'glanced',
#   'could',
#   'caught',
#   'looked',
#   'did',
#   'was',
#   'added',
#   'felt',
#   'remarked.',
#   "didn't",
#   'was',
#   'quietly',
#   'waited',
#   'coming.',
#   'indignantly,',
#   'looked',
#   'angrily.',
#   'for',
#   'said',
#   'hastily',
#   'thought',
#   'considered',
#   'had',
#   'replied',
#   'felt',
#   'again.',
#   'replied:',
#   'sighed',
#   'cautiously',
#   'thoughtfully:',
#   'asked.',
#   'ventured',
#   'gently',
#   'tried',
#   'replied',
#   'did',
#   'was',
#   'said',
#   'rather',
#   'was',
#   'did',
#   'said',
#   'was',
#   'could',
#   'as',
#   'thought',
#   'looked',
#   'recognised',
#   'was',
#   'very',
#   'for',
#   'joined',
#   'gave',
#   'thought',
#   'found',
#   'soon',
#   'began',
#   'waited',
#   'put',
#   'began,',
#   'as',
#   'thought',
#   'an',
#   'could',
#   'appeared,',
#   'could',
#   'was',
#   'ventured',
#   'did',
#   'whispered,',
#   'thought',
#   'cautiously',
#   'remarked.',
#   'said;',
#   'said',
#   'sharply,',
#   'looked',
#   'was',
#   'heard',
#   'alone',
#   'did',
#   'could',
#   'thought',
#   'was',
#   'asked.',
#   'could',
#   'indignantly.',
#   'ventured',
#   'doubtfully:',
#   'did',
#   'went',
#   'timidly.',
#   'replied',
#   'was',
#   'looked',
#   'asked',
#   'in',
#   'a',
#   'began',
#   'said',
#   'said;',
#   'did',
#   'was',
#   'replied,',
#   'by',
#   'panted',
#   'quite',
#   'had',
#   'whispered',
#   'began',
#   'could',
#   'could',
#   'felt',
#   'very',
#   'more',
#   'guessed',
#   'watched',
#   'as',
#   'looked',
#   'could',
#   'loudly.',
#   "dear!'",
#   'got',
#   'and',
#   'herself,'],
#  'was': ['beginning',
#   'reading,',
#   'considering',
#   'nothing',
#   'just',
#   'to',
#   'very',
#   'going',
#   'coming',
#   'too',
#   'labelled',
#   'empty:',
#   'very',
#   'not',
#   'no',
#   'good',
#   'rather',
#   'nothing',
#   'the',
#   'dozing',
#   'walking',
#   'over.',
#   'not',
#   'all',
#   'another',
#   'still',
#   'not',
#   'just',
#   'close',
#   'no',
#   'lit',
#   'ever',
#   'nothing',
#   'that',
#   'too',
#   'a',
#   'not',
#   'a',
#   'all',
#   'not',
#   'NOT',
#   'indeed:',
#   'now',
#   'now',
#   'going',
#   'too',
#   'playing',
#   'very',
#   'lying',
#   'growing,',
#   'quite',
#   'so',
#   'now',
#   'as',
#   'more',
#   'a',
#   'coming.',
#   'the',
#   'ready',
#   'very',
#   'I',
#   'surprised',
#   'talking.',
#   'now',
#   'going',
#   'the',
#   'holding,',
#   'shut',
#   'lying',
#   'so',
#   'up',
#   'that',
#   'in',
#   'nine',
#   'now,',
#   'only',
#   'the',
#   'bristling',
#   'trembling',
#   'swimming',
#   'quite',
#   'high',
#   'getting',
#   'no',
#   'favoured',
#   'soon',
#   'moderate.',
#   'going',
#   'no',
#   'not',
#   'over.',
#   'exactly',
#   'to',
#   'over',
#   'speaking,',
#   'something',
#   'quite',
#   'always',
#   'soon',
#   'coming',
#   'the',
#   'looking',
#   'so',
#   'a',
#   'just',
#   'no',
#   'too',
#   'not',
#   'very',
#   'much',
#   'the',
#   'now',
#   'pressed',
#   'just',
#   'a',
#   'Bill,',
#   'a',
#   'it,',
#   'a',
#   'delighted',
#   'small',
#   'in',
#   'peering',
#   'looking',
#   'terribly',
#   'very',
#   'quite',
#   'a',
#   'on',
#   'sitting',
#   'not',
#   'another',
#   'as',
#   'silence',
#   'the',
#   'losing',
#   'exactly',
#   'out',
#   'perfectly',
#   'a',
#   'no',
#   'shrinking',
#   'pressed',
#   'hardly',
#   'an',
#   'moving',
#   'delighted',
#   'going',
#   'beating',
#   'more',
#   'no',
#   'beginning',
#   'thinking',
#   'a',
#   'such',
#   'quite',
#   'so',
#   'in',
#   'opened',
#   'all',
#   'gone,',
#   'sitting',
#   'a',
#   'looking',
#   'speaking,',
#   'full',
#   'sitting',
#   'leaning',
#   'certainly',
#   'sneezing',
#   'sitting',
#   'not',
#   'good',
#   'addressed',
#   'trying',
#   'howling',
#   'quite',
#   'busily',
#   'a',
#   'snorting',
#   'as',
#   'to',
#   'the',
#   'only',
#   'impossible',
#   'just',
#   'neither',
#   'just',
#   'a',
#   'not',
#   'getting',
#   'looking',
#   'said',
#   'in',
#   'the',
#   'thatched',
#   'so',
#   'a',
#   'sitting',
#   'a',
#   'nothing',
#   'YOUR',
#   'his',
#   'the',
#   'looking',
#   'the',
#   'the',
#   'certainly',
#   'going',
#   'at',
#   'a',
#   'beginning',
#   'the',
#   'a',
#   'getting',
#   'silent.',
#   'going',
#   'more',
#   'at',
#   'about',
#   'for',
#   'to',
#   'a',
#   'talking',
#   'said,',
#   'rather',
#   'the',
#   'silent.',
#   'evidently',
#   'walking',
#   'peeping',
#   'all',
#   'in',
#   'going',
#   'going',
#   'very',
#   'in',
#   'generally',
#   'a',
#   'in',
#   'looking',
#   'mouth',
#   'enough',
#   'close',
#   'passing',
#   'going',
#   'in',
#   'her',
#   'engaged',
#   'gone',
#   'over,',
#   'surprised',
#   'a',
#   'appealed',
#   'a',
#   'this',
#   'gone,',
#   'very',
#   'only',
#   'a',
#   'VERY',
#   'exactly',
#   'an',
#   'not',
#   'beginning',
#   'linked',
#   'gone',
#   'too',
#   'out',
#   'so',
#   'a',
#   'very',
#   'an',
#   "that?'",
#   "Mystery,'",
#   'an',
#   'THAT',
#   'an',
#   'quite',
#   'over',
#   'thoroughly',
#   'going',
#   'a',
#   'a',
#   'so',
#   'saying,',
#   'a',
#   'dreadfully',
#   'all',
#   'only',
#   'heard',
#   'standing',
#   'the',
#   'a',
#   'quite',
#   'the',
#   'certainly',
#   'obliged',
#   'talking.',
#   'Bill,',
#   'obliged',
#   'of',
#   'the',
#   'sent',
#   'beginning',
#   'as',
#   'room',
#   'sitting',
#   'immediately',
#   'done.',
#   'some',
#   'immediately',
#   'suppressed.',
#   'reading',
#   'out',
#   'the',
#   'in',
#   'waving',
#   'near',
#   'written',
#   'a',
#   'the',
#   'that',
#   'trickling',
#   'a',
#   'gently',
#   'her',
#   'sneezing'],
#  'beginning': ['to',
#   'of',
#   'to',
#   'to',
#   'to',
#   'with',
#   "again?'",
#   'very',
#   'to',
#   'to',
#   'to'],
#  'to': ['get',
#   'do:',
#   'hear',
#   'itself,',
#   'her',
#   'have',
#   'her',
#   'take',
#   'see',
#   'get',
#   'think',
#   'look',
#   'wonder',
#   'happen',
#   'look',
#   'see',
#   'her',
#   'drop',
#   'put',
#   'herself,',
#   'an',
#   'listen',
#   'her,',
#   'say',
#   'say.)',
#   'come',
#   'ask',
#   'curtsey',
#   'ask:',
#   'do,',
#   'get',
#   'herself,',
#   'dream',
#   'her',
#   'her',
#   'be',
#   'hear',
#   'be',
#   'get',
#   'one',
#   'her',
#   'get',
#   "begin.'",
#   'think',
#   'be',
#   'the',
#   'say',
#   'do',
#   'disagree',
#   'taste',
#   'see',
#   'shrink',
#   'herself,',
#   'fancy',
#   'the',
#   'the',
#   'climb',
#   'herself,',
#   'leave',
#   'bring',
#   'box',
#   'be',
#   'be',
#   'make',
#   'herself,',
#   'feel',
#   'find',
#   'be',
#   'happen,',
#   'go',
#   'work,',
#   'speak',
#   'be',
#   'trouble',
#   "them,'",
#   'go!',
#   'herself',
#   "one's",
#   'the',
#   'look',
#   'get',
#   'cry',
#   'be',
#   'see',
#   'himself',
#   'ask',
#   'see',
#   'know.',
#   'twenty',
#   'repeat',
#   'do:--',
#   'grin,',
#   'go',
#   'no',
#   'play',
#   'learn!',
#   'see',
#   'the',
#   'measure',
#   'avoid',
#   'find',
#   'the',
#   'her',
#   'herself.',
#   'the',
#   'the',
#   'on',
#   'find',
#   'be',
#   'make',
#   'this',
#   'a',
#   'her',
#   'wink',
#   'quiver',
#   'cats',
#   'herself,',
#   'nurse--and',
#   'the',
#   'change',
#   'show',
#   'a',
#   'her:',
#   'the',
#   'go,',
#   'the',
#   'them,',
#   'get',
#   'Alice',
#   'find',
#   'tell',
#   'be',
#   'be',
#   'me!',
#   'by',
#   'usurpation',
#   'go',
#   'meet',
#   'Alice',
#   'dry',
#   'its',
#   'hide',
#   "say,'",
#   'get',
#   'know,',
#   'speak,',
#   'say',
#   'explain',
#   'do',
#   'try',
#   'know',
#   'give',
#   'Alice',
#   'do,',
#   'Alice.',
#   'laugh;',
#   'say,',
#   'eat',
#   'be',
#   'tell',
#   'tell',
#   'Alice,',
#   'a',
#   'law:',
#   'do."',
#   'the',
#   'death."\'',
#   'Alice',
#   'the',
#   'make',
#   'undo',
#   'her',
#   'you',
#   'lose',
#   'try',
#   'ask',
#   'talk',
#   'its',
#   'herself',
#   'like',
#   'cry',
#   'finish',
#   'itself',
#   'be',
#   'have',
#   'her',
#   'explain',
#   'herself',
#   'herself,',
#   'see',
#   'leave',
#   'her',
#   "happen,'",
#   'herself,',
#   'stoop',
#   'save',
#   'herself',
#   'wish',
#   'kneel',
#   'herself',
#   'be',
#   'me!',
#   'read',
#   'be',
#   'grow',
#   'be',
#   'have',
#   'learn!',
#   'listen.',
#   'look',
#   'be',
#   'the',
#   'open',
#   'itself',
#   'stay',
#   'bring',
#   'go',
#   'go',
#   'go',
#   'come',
#   'herself.',
#   'put',
#   'be',
#   'herself',
#   'see',
#   'you?',
#   'tell',
#   'herself,',
#   'begin',
#   'doubt,',
#   "this,'",
#   'herself,',
#   'make',
#   'find',
#   'get',
#   "do,'",
#   'herself,',
#   'grow',
#   'my',
#   'find',
#   'set',
#   'touch',
#   'whistle',
#   'it;',
#   'eat',
#   'the',
#   'worry',
#   'keep',
#   'get',
#   'be',
#   'Alice',
#   'rest',
#   'do',
#   'grow',
#   'be',
#   'eat',
#   'eat',
#   'her',
#   'begin',
#   'turn',
#   "ME.'",
#   'the',
#   'tell',
#   'be',
#   "say!'",
#   'do,',
#   'say',
#   'his',
#   'sell',
#   'do',
#   'the',
#   'my',
#   'such',
#   "end,'",
#   'speak.',
#   "be?'",
#   "size,'",
#   'be',
#   "be.'",
#   "it!'",
#   'it',
#   'speak',
#   'herself.',
#   'make',
#   'herself,',
#   'try',
#   'be',
#   'work',
#   'eat',
#   'open',
#   'swallow',
#   'be',
#   'rise',
#   'follow,',
#   'be',
#   'her',
#   'get',
#   'them,',
#   'find',
#   'dive',
#   'be',
#   'suit',
#   'her;',
#   'see',
#   'a',
#   'invent',
#   'Alice,',
#   'me',
#   "ME,'",
#   'stop',
#   'work',
#   'her',
#   'it',
#   'herself,',
#   'be,',
#   'another!',
#   'my',
#   'get',
#   'be',
#   'come',
#   'go',
#   'nine',
#   'do',
#   'be',
#   'know',
#   'listen.',
#   'the',
#   'play',
#   'play',
#   'run',
#   'the',
#   'pieces.',
#   'get',
#   'her,',
#   'herself;',
#   'get',
#   'pieces',
#   'get',
#   'get',
#   'be',
#   'herself,',
#   'drive',
#   'think',
#   "do?'",
#   "him,'",
#   'the',
#   'be',
#   'herself,',
#   'ear.',
#   'speak',
#   'the',
#   'her,',
#   'have',
#   'introduce',
#   'fix',
#   'work',
#   'say',
#   'get',
#   'turn',
#   'see',
#   'take',
#   'be',
#   'it',
#   'your',
#   'annoy,',
#   'my',
#   'Alice,',
#   'play',
#   'hold',
#   'twist',
#   'prevent',
#   'kill',
#   'leave',
#   'see',
#   'see',
#   'turn',
#   'do',
#   'say',
#   'think',
#   'herself,',
#   'do',
#   'carry',
#   'see',
#   'herself,',
#   'herself,',
#   'change',
#   'be',
#   'go',
#   'get',
#   'do',
#   'go',
#   'queer',
#   "ask.'",
#   'see',
#   'live.',
#   'herself;',
#   'go',
#   'about',
#   'herself',
#   'see',
#   'offer',
#   'sit',
#   'make',
#   "it?'",
#   'be',
#   'break',
#   'Alice:',
#   'his',
#   'say',
#   'have',
#   'remark',
#   'Alice',
#   "Time!'",
#   'beat',
#   'begin',
#   'whisper',
#   'Time,',
#   'itself',
#   'half-past',
#   'sing',
#   'pinch',
#   'make',
#   'wash',
#   'the',
#   'ask.',
#   'fancy',
#   'herself',
#   'Alice,',
#   'take',
#   'say',
#   'this:',
#   'some',
#   'the',
#   'think',
#   'go',
#   'draw,',
#   'offend',
#   'the',
#   'notice',
#   "draw,'",
#   'put',
#   'the',
#   'herself,',
#   'work',
#   'watch',
#   'them',
#   'be',
#   'fall',
#   'have',
#   'find',
#   'see',
#   'lie',
#   'lie',
#   'Alice,',
#   'the',
#   'Alice,',
#   'herself,',
#   'the',
#   'the',
#   'the',
#   'the',
#   'execute',
#   'Alice',
#   'her',
#   'your',
#   'double',
#   'stand',
#   'make',
#   'give',
#   'begin',
#   'find',
#   'send',
#   'other',
#   'the',
#   'feel',
#   'be',
#   'be',
#   'herself',
#   'talk',
#   'speak',
#   "it,'",
#   'listen',
#   'her.',
#   'think',
#   'have',
#   'them--and',
#   'go',
#   'win,',
#   'Alice,',
#   'introduce',
#   'be',
#   'Alice',
#   'the',
#   'fly',
#   'the',
#   'find',
#   'by',
#   'settle',
#   'her,',
#   'make',
#   'cut',
#   'do',
#   'begin',
#   'talk',
#   'say',
#   'the',
#   'the',
#   'the',
#   'see',
#   'find',
#   'herself',
#   'herself,',
#   'her',
#   'talk.',
#   'remark.',
#   "Alice's",
#   'her:',
#   'rest',
#   'be',
#   'herself.',
#   'have',
#   'agree',
#   'everything',
#   'this',
#   'be"--or',
#   'be',
#   'others',
#   'them',
#   'be',
#   'what',
#   'say',
#   'say',
#   "think,'",
#   'feel',
#   'fly;',
#   "Alice's",
#   'tremble.',
#   'Alice;',
#   'say',
#   'the',
#   'the',
#   'leave',
#   'do',
#   'Alice,',
#   'the',
#   'herself,',
#   'see',
#   'hear',
#   'stay',
#   'go',
#   'itself,',
#   'Alice.',
#   'the',
#   'know',
#   'herself,',
#   'come,',
#   'school',
#   'call',
#   'be',
#   'sink',
#   'the',
#   'school',
#   'school',
#   'a',
#   'learn',
#   'begin',
#   'say.',
#   'beautify',
#   'uglify',
#   'ask',
#   'the',
#   "learn?'",
#   'come',
#   'the',
#   "him,'",
#   "say.'",
#   'change',
#   "day.'",
#   'Alice,',
#   'speak,',
#   'work',
#   'a',
#   'say',
#   "partners--'",
#   'sea',
#   'land',
#   'see',
#   'the',
#   'mark',
#   'a',
#   'sea!"',
#   'France--',
#   "watch,'",
#   'the',
#   'the',
#   'the',
#   'sea.',
#   'fall',
#   'the',
#   'have',
#   'ME,',
#   'yesterday,',
#   'her,',
#   'the',
#   'the',
#   'hear',
#   "begin.'",
#   'repeat',
#   'say',
#   'have',
#   'change',
#   'disobey,',
#   'pocket',
#   'do',
#   'sing',
#   'sing',
#   'repeat',
#   'guard',
#   'look',
#   'be',
#   'pass',
#   'find',
#   'herself,',
#   'see',
#   'say',
#   'herself,',
#   'the',
#   'put',
#   'make',
#   'spell',
#   'ask',
#   'tell',
#   'write',
#   'the',
#   'come',
#   'have',
#   'the',
#   'shillings',
#   'the',
#   'the',
#   "sell,'",
#   'encourage',
#   'the',
#   'grow',
#   'remain',
#   'her.',
#   'grow',
#   'the',
#   'one',
#   'see',
#   'you',
#   'put',
#   'one',
#   'the',
#   'the',
#   'see',
#   'herself.',
#   'the',
#   'move.',
#   'herself;',
#   'them,',
#   'work',
#   'write',
#   'do',
#   'Alice.',
#   'the',
#   'write',
#   'himself',
#   'look',
#   'herself.',
#   'be',
#   'the',
#   'come',
#   'be',
#   'nobody,',
#   'the',
#   'her,',
#   'him:',
#   'be',
#   'you,',
#   'be',
#   'you',
#   'set',
#   'explain',
#   'find',
#   'see',
#   'the',
#   'himself:',
#   'the',
#   'the',
#   'her',
#   'beat',
#   'your',
#   'keep',
#   'listen,',
#   'execution--once',
#   'open',
#   'dull',
#   'the',
#   'tinkling',
#   'the',
#   'the',
#   'herself'],
#  'get': ['very',
#   'out',
#   'rather',
#   'out',
#   'out',
#   'her',
#   'into',
#   'through',
#   'to',
#   'to',
#   'dry',
#   'dry',
#   'us',
#   'me',
#   'ready',
#   'out."',
#   'out',
#   'any',
#   'in',
#   'hold',
#   'through',
#   'hold',
#   'used',
#   'her',
#   'into',
#   "in?'",
#   "in?'",
#   "in?'",
#   'in',
#   'an',
#   'ready',
#   'it',
#   "to,'",
#   "SOMEWHERE,'",
#   'what',
#   'used',
#   'away',
#   'them',
#   'the',
#   'up',
#   'on',
#   'to',
#   'into'],
#  'very': ['tired',
#   'sleepy',
#   'deep',
#   'deep,',
#   'slowly,',
#   'likely',
#   'much',
#   'like',
#   'earnestly,',
#   'little',
#   'few',
#   'well',
#   'nice,',
#   'soon',
#   'good',
#   'seldom',
#   'fond',
#   'small',
#   'soon',
#   'hot,',
#   'little!',
#   'glad',
#   'likely',
#   'tired',
#   'clear',
#   'soon.',
#   'politely:',
#   'gravely.',
#   'absurd,',
#   'humbly:',
#   'angrily.',
#   'carefully,',
#   'lonely',
#   'good-naturedly',
#   'soon',
#   'uncomfortable,',
#   'neatly',
#   'likely',
#   'like',
#   'little',
#   'much,',
#   'politely,',
#   "confusing.'",
#   'queer',
#   'gravely,',
#   'melancholy',
#   'white;',
#   'supple',
#   'good',
#   'difficult',
#   'sudden',
#   'sorry',
#   'truthful',
#   'carefully,',
#   'curious',
#   'politely,',
#   'nearly',
#   'glad',
#   'anxiously',
#   'well',
#   "much,'",
#   'civil',
#   'civil',
#   "rude.'",
#   'wide',
#   'readily:',
#   'earnestly.',
#   'easy',
#   'angrily,',
#   'humbly;',
#   'cautiously:',
#   'sleepy;',
#   'much',
#   "curious!'",
#   'curious',
#   'politely;',
#   'loudly',
#   'carefully,',
#   'humble',
#   'much',
#   'fine',
#   'provoking',
#   'difficult',
#   'short',
#   'uneasy:',
#   'much',
#   'glad',
#   'decidedly,',
#   'uncomfortable.',
#   'hard',
#   'glad',
#   'hopeful',
#   'well',
#   'much',
#   'politely,',
#   'soon',
#   'nearly',
#   'long',
#   'nearly',
#   "dull!'",
#   'decided',
#   'sadly',
#   'pretty',
#   'slowly',
#   'interesting',
#   'glad',
#   'interesting.',
#   'solemnly.',
#   "curious.'",
#   'queer',
#   'middle',
#   'few',
#   'busily',
#   'soon',
#   'little',
#   'curious',
#   'meekly:',
#   'sulkily',
#   'poor',
#   'curious',
#   'much',
#   'grave',
#   'diligently',
#   "important,'",
#   'respectful',
#   'tones'],
#  'tired': ['of', 'herself', 'of', 'of', 'of', 'and', 'of'],
#  'of': ['sitting',
#   'having',
#   'a',
#   'making',
#   'getting',
#   'the',
#   'it,',
#   'time',
#   'the',
#   'the',
#   'killing',
#   'the',
#   'tumbling',
#   'the',
#   'the',
#   'this',
#   'the',
#   'milk',
#   'way,',
#   'sticks',
#   'lamps',
#   'solid',
#   'the',
#   'the',
#   'them.',
#   'that',
#   'bright',
#   'very',
#   'rules',
#   'the',
#   'mixed',
#   'cherry-tart,',
#   'a',
#   'the',
#   'the',
#   'croquet',
#   'pretending',
#   'me',
#   'her',
#   'expecting',
#   'Tears',
#   'sight,',
#   'boots',
#   'the',
#   "yourself,'",
#   'tears,',
#   'feet',
#   'white',
#   'any',
#   'the',
#   'them.',
#   'things,',
#   'Paris,',
#   'Rome,',
#   'the',
#   'tears,',
#   'being',
#   'the',
#   'this',
#   'bathing',
#   'lodging',
#   'tears',
#   'any',
#   'this',
#   'swimming',
#   'speaking',
#   'its',
#   'history,',
#   'the',
#   'his',
#   'conversation.',
#   'things--I',
#   'them--and',
#   'course',
#   'authority',
#   'you,',
#   'late',
#   'Mercia',
#   'Mercia',
#   'Canterbury,',
#   'his',
#   'more',
#   'half',
#   'the',
#   'circle,',
#   'thought,',
#   'him),',
#   'voices',
#   "course,'",
#   'comfits,',
#   'this',
#   'anything',
#   'the',
#   'the',
#   'sight;',
#   'saying',
#   'an',
#   'the',
#   'footsteps',
#   'white',
#   'gloves',
#   'which',
#   'the',
#   'thing',
#   'tiny',
#   'the',
#   'being',
#   'lying',
#   'the',
#   "me?'",
#   'chance',
#   'her',
#   'the',
#   'life!',
#   'thing',
#   'one!',
#   'it',
#   'feet',
#   'it.',
#   'anything,',
#   'broken',
#   'the',
#   "THIS!'",
#   'more',
#   'broken',
#   'cucumber-frames',
#   'the',
#   'little',
#   'a',
#   'this',
#   'what',
#   '`There',
#   'voices--`Hold',
#   "WHAT?'",
#   'little',
#   'them',
#   'these',
#   'the',
#   'the',
#   'little',
#   'a',
#   'all',
#   'stick,',
#   'delight,',
#   'it;',
#   'play',
#   'short',
#   'its',
#   'breath,',
#   'the',
#   'grass,',
#   'it,',
#   'it.',
#   'the',
#   'a',
#   'her',
#   'anything',
#   'its',
#   'the',
#   'any',
#   'mind,',
#   'its',
#   "that?'",
#   'this',
#   'my',
#   'your',
#   'the',
#   'herself,',
#   'its',
#   'WHAT?',
#   "WHAT?'",
#   'sight.',
#   'it;',
#   'the',
#   'the',
#   'the',
#   'the',
#   'delight,',
#   'neck,',
#   'a',
#   'green',
#   'getting',
#   'the',
#   'sob,',
#   'trees,',
#   'sleep',
#   'them',
#   'changes',
#   'the',
#   'serpent,',
#   'adding,',
#   'mushroom',
#   'their',
#   'the',
#   'the',
#   'the',
#   'their',
#   'use',
#   'the',
#   'his',
#   'the',
#   'the',
#   'smoke',
#   'soup.',
#   'it',
#   "'em",
#   'any',
#   'this',
#   'conversation.',
#   'soup',
#   'saucepans,',
#   'them',
#   'terror.',
#   'showing',
#   'her',
#   'what',
#   "axes,'",
#   'lullaby',
#   'every',
#   'the',
#   'the',
#   'nursing',
#   'knot,',
#   'its',
#   'expressing',
#   'the',
#   'a',
#   'people',
#   'the',
#   'a',
#   'the',
#   'it',
#   'the',
#   'the',
#   'the',
#   'mushroom,',
#   'the',
#   'it:',
#   "room!'",
#   'the',
#   'you',
#   'you',
#   'the',
#   'his',
#   'tea,',
#   'nothing',
#   'the',
#   'meaning',
#   'course;',
#   'Hearts,',
#   'this.',
#   'a',
#   'eating',
#   'living',
#   'a',
#   'a',
#   'the',
#   'a',
#   'a',
#   'things--everything',
#   'a',
#   'a',
#   'rudeness',
#   'the',
#   'her',
#   'the',
#   'it',
#   'the',
#   'them',
#   'YOUR',
#   "onions.'",
#   'all',
#   'them',
#   'many',
#   'them,',
#   'Hearts,',
#   'all',
#   'such',
#   'a',
#   'Hearts,',
#   'cards,',
#   "them!'",
#   'the',
#   'her',
#   "MINE.'",
#   'the',
#   "execution.'",
#   'laughter.',
#   'thunder,',
#   'crawling',
#   'the',
#   'me?',
#   'beheading',
#   'escape,',
#   "them.'",
#   'the',
#   'it',
#   'it',
#   'the',
#   'mine--a',
#   'it',
#   'settling',
#   'the',
#   'things',
#   'her',
#   'them',
#   'the',
#   'way',
#   'sight:',
#   'the',
#   'life.',
#   'nothing',
#   'the',
#   'rule,',
#   'that',
#   'keeping',
#   'that',
#   'THAT',
#   'the',
#   'themselves."\'',
#   'finding',
#   'your',
#   'that',
#   'a',
#   'putting',
#   'that',
#   'mine,',
#   'yours."\'',
#   'that',
#   'everything',
#   "present!'",
#   'her',
#   'her',
#   'them,',
#   'the',
#   'course',
#   'half',
#   'execution.',
#   'breath,',
#   "one,'",
#   'executions',
#   'the',
#   'sight:',
#   'rock,',
#   'tears,',
#   'you,',
#   "`Hjckrrh!'",
#   'the',
#   'yourself',
#   'educations--in',
#   'great',
#   'the',
#   'the',
#   'course,',
#   'Arithmetic--',
#   '"Uglification,"\'',
#   "uglifying!'",
#   'one',
#   'a',
#   'the',
#   'its',
#   "it?'",
#   "course?'",
#   'course',
#   'great',
#   "course,'",
#   'great',
#   'YOUR',
#   'authority',
#   'the',
#   'the',
#   'the',
#   'the',
#   'repeating',
#   'the',
#   'the',
#   'the',
#   'the',
#   'beautiful',
#   'beautiful',
#   'the',
#   '`The',
#   'the',
#   'the',
#   'Hearts',
#   'little',
#   'cards:',
#   'parchment',
#   'the',
#   'tarts',
#   'this,',
#   'justice',
#   'nearly',
#   'his',
#   'them',
#   'it:',
#   'her',
#   'it',
#   'the',
#   'them',
#   'the',
#   'course,',
#   'taking',
#   'it;',
#   'the',
#   'very',
#   'Hearts,',
#   'Hearts,',
#   'bread-and-butter',
#   'March,',
#   'the',
#   'my',
#   'his',
#   'the',
#   'the',
#   'the',
#   'the',
#   'the',
#   'the',
#   'the',
#   'the',
#   'the',
#   'the',
#   'trials,',
#   'the',
#   'singers.',
#   'the',
#   'sight',
#   'sight,',
#   'court!',
#   'great',
#   'his',
#   'the',
#   'her',
#   'the',
#   'a',
#   'goldfish',
#   'great',
#   'the',
#   'idea',
#   'being',
#   'the',
#   'the',
#   "course,'",
#   'course,',
#   'the',
#   'the',
#   "verses.'",
#   'the',
#   'hands',
#   'the',
#   'you?',
#   'evidence',
#   'them',
#   'interrupting',
#   'meaning',
#   'meaning',
#   'them',
#   'trouble,',
#   'cardboard.)',
#   'course--',
#   'having',
#   'her',
#   "cards!'",
#   'fright',
#   'anger,',
#   'her',
#   'hers',
#   'little',
#   'little',
#   'her',
#   'her',
#   'her',
#   'the',
#   'the',
#   'the',
#   'the',
#   'the',
#   'the',
#   'the',
#   'the',
#   'the',
#   'the',
#   'the',
#   'the',
#   'the',
#   'hers',
#   'her',
#   'Wonderland',
#   'long'],
#  'sitting': ['by',
#   'on',
#   'on',
#   'on',
#   'on',
#   'on',
#   'on',
#   'between',
#   'sad',
#   'next'],
#  'by': ['her',
#   'her.',
#   'this',
#   'a',
#   'the',
#   'wild',
#   'the',
#   'it,',
#   "railway,'",
#   'being',
#   'the',
#   'the',
#   'the',
#   'talking',
#   'mice',
#   'the',
#   'two',
#   "that?'",
#   'this',
#   'his',
#   'another',
#   'producing',
#   'it,',
#   'this',
#   'seeing',
#   'the',
#   'this',
#   'the',
#   'taking',
#   'mistake;',
#   'without',
#   'the',
#   'all',
#   'the',
#   'this',
#   'way',
#   'everybody',
#   'the',
#   'the',
#   'a',
#   'an',
#   'the',
#   'his',
#   'his',
#   'far',
#   'the',
#   'the',
#   'the',
#   'the',
#   'the',
#   'the',
#   'the',
#   'this'],
#  'her': ['sister',
#   'sister',
#   'own',
#   'feel',
#   'that',
#   'feet,',
#   'mind',
#   'and',
#   'great',
#   'lessons',
#   'knowledge,',
#   'saucer',
#   'very',
#   'feet',
#   'was',
#   'great',
#   'head',
#   'face',
#   'best',
#   'eyes;',
#   'own',
#   'eye',
#   'hand',
#   'head',
#   'feet,',
#   'head',
#   'eyes',
#   "waiting!'",
#   'hair',
#   'hands',
#   'lap',
#   'voice',
#   'eyes',
#   'hands,',
#   'foot',
#   'chin',
#   'life,',
#   'way',
#   "brother's",
#   'rather',
#   'to',
#   'knowledge',
#   'French',
#   'paws',
#   'face--and',
#   'any',
#   'as',
#   'life.',
#   'eyes',
#   'hand',
#   'pocket,',
#   'once',
#   'idea',
#   'daughter',
#   'pet:',
#   'after',
#   'swim',
#   'in',
#   'way',
#   'eye',
#   'lips.',
#   'head',
#   'neck',
#   'head.',
#   'ever',
#   'hand,',
#   'hand',
#   'foot',
#   'in',
#   'head.',
#   'head',
#   'look',
#   'with',
#   'up',
#   'coaxing.',
#   'escape;',
#   'at',
#   'that',
#   'eyes',
#   'or',
#   'in',
#   'anger',
#   'something',
#   'hands,',
#   'life',
#   'temper.',
#   'arms',
#   'chin:',
#   'foot!',
#   'foot,',
#   'mouth;',
#   'shoulders',
#   'hands',
#   'head,',
#   'head',
#   'neck',
#   'draw',
#   'face,',
#   'violently',
#   'neck',
#   'hands,',
#   'usual',
#   'to',
#   'reach',
#   'knowledge.',
#   "head!'",
#   'child',
#   'as',
#   'as',
#   'to',
#   'too',
#   'question.',
#   'promise.',
#   'going,',
#   'way',
#   'pocket)',
#   'face',
#   'head',
#   'own',
#   'own',
#   'for',
#   'head!',
#   'arm,',
#   'side.',
#   'face.',
#   'ear,',
#   'life;',
#   'flamingo:',
#   'arm,',
#   'face,',
#   "head!'",
#   'very',
#   'flamingo,',
#   'sentence',
#   'turn',
#   'hedgehog.',
#   'flamingo',
#   'arm,',
#   'friend.',
#   "here.'",
#   'arm',
#   'in',
#   'so',
#   'voice',
#   'ear.',
#   'chin',
#   'sharp',
#   'sharp',
#   'favourite',
#   'arms',
#   'choice,',
#   'back',
#   "head!'",
#   'fancy,',
#   'next',
#   'something',
#   'toes',
#   'about',
#   'answer.',
#   'adventures',
#   'repeating',
#   'try',
#   'to',
#   'head',
#   'face',
#   'hands,',
#   '"Turtle',
#   'age',
#   'spectacles,',
#   'a',
#   'hand,',
#   'surprise,',
#   'skirt,',
#   'very',
#   'head,',
#   'haste,',
#   'one,',
#   "head!'",
#   'voice.',
#   'full',
#   'head',
#   'sister,',
#   'face.',
#   'sister;',
#   'sister,',
#   'sister',
#   'sister',
#   'head',
#   'hand,',
#   'wonderful',
#   'dream:--',
#   'knee,',
#   'voice,',
#   'head',
#   'eyes--and',
#   'became',
#   'little',
#   'feet',
#   'unfortunate',
#   'riper',
#   'childhood:',
#   'other',
#   'own'],
#  'sister': ['on', 'was', 'kissed', 'sat', 'of'],
#  'on': ['the',
#   'like',
#   'saying',
#   'to',
#   'it',
#   'the',
#   'it,',
#   'it,',
#   'it',
#   'going',
#   'a',
#   'which',
#   'the',
#   'in',
#   'your',
#   'planning',
#   'one',
#   'crying',
#   'all',
#   'talking:',
#   'just',
#   'her',
#   'one',
#   'shrinking',
#   'the',
#   'the',
#   'such',
#   'eagerly:',
#   'the',
#   'it,',
#   'now,',
#   'the',
#   'puzzling',
#   'the',
#   'messages',
#   'it',
#   'growing,',
#   'the',
#   'growing,',
#   'the',
#   'the',
#   'the',
#   'both',
#   'the',
#   'tiptoe,',
#   'the',
#   'your',
#   'the',
#   'the',
#   'the',
#   'the',
#   'within--a',
#   'without',
#   'a',
#   'the',
#   'again:--',
#   'one,',
#   'its',
#   'again:',
#   'for',
#   'a',
#   'where',
#   '`And',
#   'in',
#   'a',
#   'it,',
#   'it',
#   'hearing',
#   'good',
#   'so',
#   'in',
#   'both',
#   "treacle,'",
#   'as',
#   'for',
#   'being',
#   'it',
#   "others!'",
#   'a',
#   'her',
#   'their',
#   'their',
#   'one',
#   'their',
#   'between',
#   'rather',
#   'the',
#   'with',
#   'the',
#   'a',
#   'at',
#   'in',
#   'his',
#   'the',
#   'eagerly.',
#   'again:--',
#   'her',
#   'my',
#   'the',
#   'in',
#   'the',
#   'each',
#   'with',
#   'with',
#   'in',
#   'the',
#   'their',
#   'each',
#   'slates.',
#   'his',
#   'their',
#   'the',
#   'the',
#   'a',
#   'the',
#   'their',
#   'her',
#   'the',
#   'second',
#   'which',
#   'one',
#   'the',
#   "better.'",
#   'to',
#   'their',
#   'to',
#   'the',
#   'his',
#   'till',
#   'their',
#   'his',
#   'muttering',
#   '"THEY',
#   'the',
#   'his',
#   'the',
#   'her',
#   'the'],
#  'bank,': ['and', 'with'],
#  'and': ['of',
#   'stupid),',
#   'picking',
#   'looked',
#   'then',
#   'burning',
#   'fortunately',
#   'then',
#   'to',
#   'make',
#   'noticed',
#   'book-shelves;',
#   'there',
#   'pictures',
#   'though',
#   "that's",
#   'went',
#   'sometimes,',
#   'had',
#   'saying',
#   'dry',
#   'the',
#   'she',
#   'the',
#   'was',
#   'whiskers,',
#   'when',
#   'up',
#   "Alice's",
#   'behind',
#   'to',
#   'found',
#   'looked',
#   'wander',
#   'those',
#   'round',
#   'eaten',
#   'other',
#   'that',
#   'she',
#   'finding',
#   'hot',
#   'her',
#   'when',
#   'she',
#   'when',
#   'cried.',
#   'sometimes',
#   'once',
#   'found',
#   'if',
#   'I',
#   'said',
#   'she',
#   'stupid',
#   'very',
#   "curiouser!'",
#   'stockings',
#   'she',
#   'hurried',
#   'began',
#   'reaching',
#   'she',
#   'a',
#   'the',
#   'skurried',
#   'gloves,',
#   'mine',
#   "I'm",
#   'she,',
#   "I'm",
#   'four',
#   'four',
#   'Paris',
#   'Rome--no,',
#   'say',
#   'she',
#   'began',
#   'strange,',
#   'the',
#   'her',
#   'I',
#   'live',
#   'have',
#   'oh!',
#   'saying',
#   'say',
#   'then,',
#   'was',
#   'went',
#   'found',
#   'was',
#   'she',
#   'she',
#   'the',
#   'in',
#   'had',
#   'behind',
#   'she',
#   'she',
#   'seemed',
#   'seemed',
#   'washing',
#   'she',
#   "it'll",
#   'beg',
#   'all',
#   'he',
#   'making',
#   'we',
#   'swam',
#   'it',
#   'then',
#   "you'll",
#   "dogs.'",
#   'animals',
#   'a',
#   'an',
#   'several',
#   'the',
#   'a',
#   'all',
#   'uncomfortable.',
#   'after',
#   'would',
#   'must',
#   'this',
#   'listen',
#   'had',
#   'conquest.',
#   'Morcar,',
#   'Northumbria--"\'',
#   'Morcar,',
#   'Northumbria,',
#   'even',
#   'offer',
#   'no',
#   'then',
#   'there.',
#   "away,'",
#   'left',
#   'were',
#   'they',
#   'asking,',
#   'it',
#   'all',
#   'the',
#   'in',
#   'pulled',
#   'handed',
#   'took',
#   'confusion,',
#   'the',
#   'had',
#   'they',
#   'begged',
#   "D,'",
#   'a',
#   'sighing.',
#   'condemn',
#   'very',
#   'looking',
#   'walking',
#   'finish',
#   'the',
#   'walked',
#   'an',
#   'a',
#   'Alice',
#   "I'm",
#   'low-spirited.',
#   'she',
#   'was',
#   'looking',
#   'she',
#   'whiskers!',
#   'the',
#   'she',
#   'the',
#   'the',
#   'called',
#   'fetch',
#   'a',
#   'gloves--that',
#   'hurried',
#   'be',
#   'gloves.',
#   'get',
#   'on',
#   'two',
#   'a',
#   'was',
#   'put',
#   'much',
#   'had',
#   'growing,',
#   'very',
#   'she',
#   'the',
#   'one',
#   'said',
#   'she',
#   'smaller,',
#   'being',
#   'rabbits.',
#   'now',
#   'no',
#   'then',
#   'making',
#   'stopped',
#   'she',
#   'had',
#   'tried',
#   "Alice's",
#   'get',
#   'made',
#   'a',
#   'a',
#   'help',
#   'take',
#   'Alice',
#   'then;',
#   'at',
#   'made',
#   'more',
#   'the',
#   'waited',
#   'scrambling',
#   'waited',
#   'then',
#   'up',
#   'Alice',
#   'Alice',
#   'Alice',
#   'some',
#   'shouted',
#   'a',
#   'as',
#   'was',
#   'found',
#   'birds',
#   'soon',
#   'the',
#   'very',
#   'simply',
#   'while',
#   'feebly',
#   'she',
#   'held',
#   'rushed',
#   'made',
#   'the',
#   'tumbled',
#   'expecting',
#   'a',
#   'barking',
#   'its',
#   'ran',
#   'out',
#   'till',
#   'fanned',
#   'the',
#   'when',
#   'on',
#   'behind',
#   'see',
#   'peeped',
#   'her',
#   'taking',
#   'Alice',
#   'addressed',
#   'being',
#   'she',
#   'said,',
#   'as',
#   'as',
#   'came',
#   'perhaps',
#   'said,',
#   'began:--',
#   "again.'",
#   'the',
#   'that',
#   'there',
#   'she',
#   'it',
#   'began',
#   'yawned',
#   'shook',
#   'crawled',
#   'the',
#   'in',
#   'as',
#   'broke',
#   'nibbled',
#   'managed',
#   'was',
#   'was',
#   'was',
#   'added',
#   'nothing',
#   "I've",
#   "I've",
#   'more',
#   'day!',
#   "there's",
#   'what',
#   'if',
#   'every',
#   'then',
#   'untwist',
#   'she',
#   'then',
#   'growing',
#   'sometimes',
#   'began',
#   'did',
#   'Pepper',
#   'wondering',
#   'large',
#   'both',
#   'crept',
#   'this',
#   'their',
#   'when',
#   'the',
#   'knocked.',
#   'sneezing,',
#   'every',
#   'then',
#   'I',
#   'this',
#   'a',
#   'broke',
#   'off,',
#   "days.'",
#   'began',
#   'went',
#   'as',
#   'howling',
#   'a',
#   'grinning',
#   'not',
#   'went',
#   'thought',
#   'at',
#   'the',
#   'dishes.',
#   'the',
#   'down',
#   'very',
#   'night!',
#   'seemed',
#   'giving',
#   'the',
#   'down,',
#   'the',
#   'get',
#   'she',
#   'held',
#   'legs',
#   'kept',
#   'straightening',
#   'then',
#   'left',
#   'the',
#   'Alice',
#   'looked',
#   'they',
#   'she',
#   'felt',
#   'was',
#   'a',
#   'she',
#   'in',
#   'wags',
# ...
#   'she',
#   'of',
#   'conversation',
#   'there',
#   'simply--"Never',
#   'to',
#   'calmly,',
#   'questions',
#   'than',
#   'and',
#   'faintly',
#   'boldly:',
#   'bread-',
#   'evidence',
#   'the',
#   'the'],
#  'happened,': ['she', 'and'],
#  'decided': ['on', 'tone:', 'to'],
#  'once;': ['but,'],
#  'alas': ['for'],
#  'Alice!': ['when', 'It', 'Come'],
#  'table': ['for', 'to', 'as', 'and', 'in', 'set', 'was'],
#  'possibly': ['reach', 'make', 'hear'],
#  'reach': ['it:', 'the', 'half', 'at'],
#  'it:': ['she', 'there', 'it', 'a', '`No', 'there', '`I', 'they', 'for'],
#  'plainly': ['through'],
#  'glass,': ['and', 'from'],
#  'best': ['to', 'way', 'thing', 'way', 'cat', "plan.'", 'of'],
#  'climb': ['up'],
#  'legs': ['of', 'in', 'hanging'],
#  'slippery;': ['and'],
#  'trying,': ['the'],
#  'thing': ['sat',
#   'before,',
#   'to',
#   'I',
#   'to',
#   'yourself,',
#   'very',
#   'was',
#   'that',
#   'never',
#   'she',
#   "I've",
#   'is',
#   'to',
#   'is,',
#   'howled',
#   'was',
#   'grunted',
#   'at',
#   'sobbed',
#   'I',
#   'a',
#   'as',
#   'as',
#   'as',
#   'with',
#   'I',
#   'as',
#   'before,',
#   'Mock',
#   'a',
#   'I',
#   'was',
#   'about',
#   'the'],
#  'sat': ['down',
#   'down',
#   'down',
#   'for',
#   'down',
#   'down',
#   'down',
#   'silent',
#   'up',
#   'down,',
#   'still',
#   'silent',
#   'down',
#   'down',
#   'upon',
#   'still',
#   'on,'],
#  'cried.': ['`Come,', '`Wake'],
#  '`Come,': ["there's",
#   'my',
#   "there's",
#   "it's",
#   'we',
#   "THAT'S",
#   "let's",
#   "let's",
#   'that'],
#  "there's": ['no',
#   'hardly',
#   'no',
#   'no',
#   'hardly',
#   'no',
#   'half',
#   'no',
#   'any',
#   'the',
#   'nothing',
#   'no',
#   'an',
#   'an',
#   'no'],
#  'crying': ['like', 'in'],
#  "that!'": ['said', 'By', '`I', 'screamed', 'He', 'But', '`Call'],
#  'sharply;': ['`I'],
#  'advise': ['you'],
#  'leave': ['off', 'the', 'it', 'off', "off,'", 'the'],
#  "minute!'": ['She'],
#  'generally': ['gave', 'happens', 'a', 'a', 'takes'],
#  'gave': ['herself',
#   'a',
#   'one',
#   'to',
#   'the',
#   'a',
#   'a',
#   'her',
#   'me',
#   'her',
#   'him',
#   'us',
#   'a'],
#  'advice,': ['(though'],
#  '(though': ['she'],
#  'seldom': ['followed'],
#  'followed': ['it),', 'a', 'him:', 'the', 'her', 'by', 'them,', 'him'],
#  'it),': ['and', 'and'],
#  'sometimes': ['she', 'taller', 'shorter,', 'choked'],
#  'scolded': ['herself'],
#  'severely': ['as', 'to', '`Who'],
#  'bring': ['tears', 'but'],
#  'tears': ['into', 'again', 'which', 'running'],
#  'eyes;': ['and'],
#  'remembered': ['trying', 'how', 'having', 'the', 'that'],
#  'box': ['her', 'that', 'of'],
#  'cheated': ['herself'],
#  'game': ['of', 'of', 'began.', 'indeed.', 'was', 'was'],
#  'croquet': ['she', 'with', 'with'],
#  'playing': ['against', 'the'],
#  'against': ['herself,',
#   'the',
#   'the',
#   'the',
#   'it,',
#   'a',
#   'her',
#   'one',
#   'each'],
#  'child': ['was', 'again,', 'away'],
#  'fond': ['of', 'of', 'she'],
#  'pretending': ['to'],
#  'two': ['people.',
#   'people!',
#   'feet',
#   'or',
#   'guinea-pigs,',
#   'the',
#   'sides',
#   'she',
#   'reasons.',
#   'she',
#   'feet',
#   'were',
#   'to',
#   'and',
#   'sobs',
#   'creatures,',
#   'creatures',
#   'Pennyworth',
#   'or',
#   'miles'],
#  'people.': ['`But'],
#  '`But': ["it's",
#   'who',
#   'who',
#   'she',
#   "you're",
#   "then,'",
#   "I'm",
#   "I'm",
#   'perhaps',
#   'what',
#   'perhaps',
#   'I',
#   'what',
#   'why',
#   'I',
#   'they',
#   "everything's",
#   'about',
#   'what'],
#  "now,'": ['thought', 'thought', 'she', 'she'],
#  '`to': ['pretend', 'go', 'speak', 'be'],
#  'pretend': ['to'],
#  'people!': ['Why,'],
#  'hardly': ['enough',
#   'room',
#   'know--No',
#   'know,',
#   'suppose',
#   'room',
#   'hear',
#   'finished',
#   'worth',
#   'knew',
#   "breathe.'"],
#  'enough': ['of',
#   'to',
#   'yet--Oh!',
#   'to',
#   'hatching',
#   'to',
#   'for',
#   'of',
#   'about',
#   'to'],
#  'left': ['to',
#   'off',
#   'alone.',
#   'foot,',
#   'off',
#   "alive!'",
#   'off',
#   'off,',
#   'no',
#   'off',
#   'the',
#   'off',
#   'her,'],
#  'ONE': ['respectable', 'with'],
#  'respectable': ["person!'"],
#  "person!'": ['Soon'],
#  'Soon': ['her'],
#  'eye': ['fell', 'fell', 'was', 'chanced'],
#  'glass': ['box', 'table', 'table', 'table.'],
#  'lying': ['under', 'down', 'on', 'down', 'round', 'on', 'fast', 'on'],
#  'table:': ['she'],
#  'cake,': ['on', 'but'],
#  '`EAT': ["ME'"],
#  'currants.': ['`Well,'],
#  '`Well,': ["I'll",
#   'perhaps',
#   "it's",
#   'I',
#   'perhaps',
#   'perhaps',
#   "I've",
#   'I',
#   'be',
#   "then,'",
#   "I'd",
#   'of',
#   'it',
#   "then,'",
#   'there',
#   'I',
#   'I',
#   'at',
#   'if',
#   'I'],
#  "it,'": ['said',
#   'said',
#   'she',
#   'said',
#   'said',
#   'said',
#   'said',
#   'added',
#   'said',
#   'she',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'said',
#   'but',
#   'said'],
#  'makes': ['me',
#   'me',
#   'rather',
#   'people',
#   'them',
#   'them',
#   'you',
#   'the',
#   'them',
#   'my',
#   'the'],
#  'grow': ['larger,',
#   'smaller,',
#   'large',
#   'any',
#   'up,',
#   'up',
#   'to',
#   'up',
#   'taller,',
#   "shorter.'",
#   'larger',
#   "here,'",
#   'at'],
#  'larger,': ['I', 'it', 'sir,'],
#  'can': ['reach',
#   'creep',
#   'remember',
#   'go',
#   'talk:',
#   'find',
#   'do',
#   'you',
#   'kick',
#   'listen',
#   'see',
#   "say.'",
#   'thoroughly',
#   'guess',
#   'find',
#   'draw',
#   'find',
#   'EVEN',
#   'have',
#   'do',
#   'really',
#   'tell',
#   "be,'",
#   'hardly',
#   'explain',
#   "you?'",
#   'be'],
#  'key;': ['and'],
#  'smaller,': ['I', 'and', 'I'],
#  'creep': ['under'],
#  'door;': ['so'],
#  'garden,': ['and', 'among', 'called', 'where', 'and'],
#  "don't": ['care',
#   'like',
#   'know',
#   'believe',
#   "think,'",
#   'like',
#   'want',
#   'reach',
#   'be',
#   "see,'",
#   'keep',
#   'believe',
#   'like',
#   'know',
#   'know',
#   'bother',
#   'take',
#   'much',
#   'want',
#   'see',
#   'quite',
#   'know',
#   'know',
#   'understand.',
#   "think--'",
#   'think',
#   'think',
#   'seem',
#   'like',
#   'look',
#   'remember',
#   'put',
#   'trouble',
#   'talk',
#   'give',
#   'even',
#   'know',
#   'speak',
#   'see',
#   'know',
#   'know',
#   'want',
#   'explain',
#   'be',
#   'even',
#   'believe',
#   "know,'",
#   'FIT'],
#  'care': ['which', "where--'", 'of', 'of'],
#  "happens!'": ['She'],
#  'ate': ['a'],
#  'bit,': ['and', 'if'],
#  'anxiously': ['to',
#   'fixed',
#   'about',
#   'about',
#   'among',
#   'at',
#   'into',
#   'looking',
#   'into',
#   'over',
#   'round,',
#   'round',
#   'at'],
#  '`Which': ['way?', 'would', 'is'],
#  'way?': ['Which'],
#  'Which': ["way?',", 'brought', 'shall'],
#  "way?',": ['holding'],
#  'holding': ['her', 'it'],
#  'growing,': ['and', 'and', 'and', 'and,'],
#  'surprised': ['to', 'to', "he'll", 'at', 'at', 'to'],
#  'remained': ['the', 'looking', 'some'],
#  'same': ['size:',
#   'when',
#   'age',
#   'as',
#   'height',
#   'size',
#   'solemn',
#   'side',
#   'tone,',
#   'thing,',
#   'thing',
#   'thing',
#   'thing',
#   'thing',
#   'thing',
#   'year',
#   'as',
#   "thing,'",
#   'words',
#   "order,'",
#   'little'],
#  'size:': ['to', 'the', 'why,'],
#  'sure,': ['this', 'she'],
#  'happens': ['when', 'when'],
#  'eats': ['cake,'],
#  'expecting': ['nothing', 'every', 'to'],
#  'happen,': ['that'],
#  'dull': ['and', 'reality--the'],
#  'stupid': ['for'],
#  'life': ['to', 'before,'],
#  'common': ['way.'],
#  'way.': ['So', '`I', 'So'],
#  'set': ['to',
#   'Dinah',
#   'about',
#   'off',
#   'to',
#   'to',
#   'to',
#   'the',
#   'out',
#   'to',
#   'to',
#   'to',
#   'of',
#   'them'],
#  'work,': ['and'],
#  'cake.': ['*'],
#  'II': ['The'],
#  'Pool': ['of'],
#  'Tears': ['`Curiouser'],
#  '`Curiouser': ['and'],
#  "curiouser!'": ['cried'],
#  'cried': ['Alice',
#   'Alice,',
#   'so',
#   'Alice',
#   'the',
#   'Alice',
#   'the',
#   'Alice',
#   'the',
#   'Alice,',
#   'out',
#   'the',
#   'the',
#   'the',
#   'the',
#   'the',
#   'out,',
#   'Alice,'],
#  'surprised,': ['that'],
#  'forgot': ['how', 'you'],
#  'speak': ['good',
#   'to',
#   'again.',
#   'first,',
#   'severely',
#   'with.',
#   'a',
#   'again.'],
#  'English);': ['`now'],
#  '`now': ["I'm"],
#  'opening': ['out', 'for', 'its'],
#  'largest': ['telescope'],
#  'telescope': ['that'],
#  'was!': ['Good-bye,'],
#  'Good-bye,': ["feet!'"],
#  "feet!'": ['(for'],
#  '(for': ['when'],
#  'far': ['off).', 'off', 'down', 'as', 'below', 'before', 'out', 'we', 'the'],
#  'off).': ['`Oh,'],
#  '`Oh,': ['my',
#   'I',
#   'do',
#   'you',
#   "I'm",
#   "there's",
#   'PLEASE',
#   'there',
#   "don't",
#   "you're",
#   'you',
#   "hush!'",
#   'I',
#   "don't",
#   'YOU',
#   'as',
#   'a',
#   'I',
#   "I've"],
#  'shoes': ['and', 'done', 'under', 'off.', 'on.'],
#  'stockings': ['for'],
#  'now,': ['dears?', 'I', 'and', 'my', 'Five!', 'only'],
#  'dears?': ["I'm"],
#  'sure': ['_I_',
#   "I'm",
#   'I',
#   'those',
#   'she',
#   "she's",
#   'as',
#   'to',
#   'I',
#   'to',
#   'I',
#   'what',
#   'whether',
#   'to',
#   'to',
#   'it'],
#  '_I_': ["shan't", "don't"],
#  "shan't": ['be', 'grow', 'be', 'go,'],
#  'able!': ['I'],
#  'deal': ['too',
#   'frightened',
#   'of',
#   'too',
#   'frightened',
#   'to',
#   'faster',
#   'on',
#   'worse',
#   'to',
#   'until'],
#  'myself': ['about', 'to'],
#  'you:': ['you'],
#  'can;': ['--but'],
#  '--but': ['I'],
#  'kind': ['to', 'of', 'of', 'of', 'of', 'of'],
#  "them,'": ['thought', 'the', 'said'],
#  '`or': ['perhaps', 'you', "you'll", "I'll", "I'll"],
#  "won't": ['walk',
#   'she',
#   'talk',
#   "indeed!'",
#   'talk',
#   "you?'",
#   'be',
#   'stand',
#   'do',
#   'interrupt',
#   'have',
#   'you,',
#   'you,',
#   'you,',
#   'you,',
#   'you',
#   'you,',
#   'you,',
#   'you,',
#   'you,',
#   'you'],
#  'want': ['to', 'to', 'to', 'YOURS:', 'to', 'to', 'a', 'YOU', 'to'],
#  'go!': ['Let'],
#  'give': ['them',
#   'the',
#   'yourself',
#   'it',
#   'the',
#   'birthday',
#   'you',
#   'all',
#   'him'],
#  'new': ['pair', 'idea', 'kind', 'idea'],
#  'pair': ['of', 'of', 'of', 'of', 'of'],
#  'boots': ['every', 'and'],
#  "Christmas.'": ['And'],
#  'planning': ['to'],
#  '`They': ['must',
#   'all',
#   'lived',
#   "couldn't",
#   'were',
#   'have',
#   'were',
#   "can't",
#   'told'],
#  "carrier,'": ['she'],
#  'thought;': ['`and'],
#  'seem,': ['sending'],
#  'sending': ['presents', 'me'],
#  'presents': ['to', 'like'],
#  "one's": ['own'],
#  'feet!': ['And'],
#  'odd': ['the'],
#  'directions': ['will'],
#  'look!': ["ALICE'S"],
#  'RIGHT': ['FOOT,'],
#  'FOOT,': ['ESQ.'],
#  'ESQ.': ['HEARTHRUG,'],
#  'HEARTHRUG,': ['NEAR'],
#  'NEAR': ['THE'],
#  'FENDER,': ['(WITH'],
#  '(WITH': ["ALICE'S"],
#  'LOVE).': ['Oh'],
#  'dear,': ['what', 'how', 'and', 'YOU', 'I', 'certainly:'],
#  'nonsense': ["I'm"],
#  "talking!'": ['Just'],
#  'Just': ['then', 'then', 'as', 'then', 'at'],
#  'struck': ['against', 'her'],
#  'roof': ['of', 'bear?--Mind', "off.'", 'was', 'of'],
#  'hall:': ['in'],
#  'fact': ['she', 'is,'],
#  'nine': ['feet', 'feet', 'inches', "o'clock"],
#  'door.': ['Poor', '`Call'],
#  'Poor': ['Alice!'],
#  'side,': ['to', 'the', 'and'],
#  'eye;': ['but', '`I'],
#  'hopeless': ['than'],
#  'ever:': ['she'],
#  'cry': ['again.', 'again,', 'of'],
#  '`You': ['ought',
#   'promised',
#   'are',
#   'insult',
#   'are',
#   'are',
#   'are',
#   'are',
#   "don't",
#   'must',
#   'should',
#   'might',
#   'might',
#   'might',
#   'mean',
#   'can',
#   'make',
#   "shan't",
#   "can't",
#   'are',
#   'ought',
#   "did,'",
#   "couldn't",
#   'know',
#   'may',
#   'ought',
#   "did!'",
#   'MUST',
#   'may',
#   "are,'"],
#  'ashamed': ['of', 'of'],
#  "yourself,'": ['said'],
#  '`a': ['great', "dog's"],
#  "you,'": ['(she', 'said', 'she', 'said', 'said', 'said'],
#  'this),': ['`to'],
#  'way!': ['Stop'],
#  'Stop': ['this'],
#  'moment,': ['I', 'splash!', 'and', 'when', '`My'],
#  "you!'": ['But', 'There', 'said'],
#  'same,': ['shedding', 'the'],
#  'shedding': ['gallons'],
#  'gallons': ['of'],
#  'tears,': ['until', '`I', 'but'],
#  'until': ['there', 'it', 'she', 'she'],
#  'pool': ['all', 'of', 'a', 'as', 'was', 'rippling'],
#  'reaching': ['half'],
#  'hall.': ['After'],
#  'heard': ['a',
#   'something',
#   'this,',
#   'a',
#   'it',
#   'a',
#   'it',
#   'the',
#   'a',
#   'before,',
#   'a',
#   'was',
#   'the',
#   'something',
#   'every',
#   'one',
#   'the',
#   'of',
#   'the',
#   'her',
#   'her',
#   'of',
#   'the',
#   'of',
#   'of',
#   'him',
#   'it',
#   'in',
#   "yet,'"],
#  'pattering': ['of', 'of', 'of'],
#  'distance,': ['and', 'and', 'screaming', 'sitting'],
#  'hastily': ['dried',
#   'put',
#   'replied;',
#   'replied;',
#   'interrupted.',
#   'said,',
#   'began'],
#  'dried': ['her'],
#  'coming.': ['It', "`There's"],
#  'returning,': ['splendidly'],
#  'splendidly': ['dressed,'],
#  'dressed,': ['with'],
#  'white': ['kid', 'kid', 'kid', 'kid', 'kid', 'one'],
#  'kid': ['gloves', 'gloves', 'gloves', 'gloves,', 'gloves:'],
#  'gloves': ['in', 'and', 'while', 'and', 'this'],
#  'fan': ['in', 'and', 'she', 'and', 'and', 'and', 'and', 'and'],
#  'other:': ['he', 'the', 'the'],
#  'he': ['came',
#   'came,',
#   'could',
#   'seems',
#   'says',
#   'went',
#   'met',
#   'finds',
#   'shook',
#   'was',
#   'handed',
#   'was',
#   "can't",
#   'might',
#   'said,',
#   'sneezes:',
#   'knows',
#   'sneezes;',
#   'can',
#   "pleases!'",
#   'SAID',
#   'said,',
#   'had',
#   'added',
#   'dipped',
#   'could',
#   'poured',
#   'replied.',
#   'said',
#   'consented',
#   'spoke,',
#   'checked',
#   'spoke,',
#   'spoke,',
#   'spoke.',
#   'called',
#   'hurried',
#   'had',
#   "wasn't",
#   'was',
#   'had',
#   'shall',
#   "hasn't",
#   'can',
#   "doesn't",
#   "wasn't",
#   'taught',
#   'went',
#   'did,',
#   "did,'",
#   'had',
#   'went',
#   'thanked',
#   'would',
#   'said',
#   'was',
#   'thought',
#   'with',
#   'is',
#   'turn',
#   'wore',
#   'did',
#   'did',
#   'had',
#   'was',
#   'stole',
#   'began,',
#   'said.',
#   'kept',
#   'bit',
#   'got',
#   'shook',
#   'would',
#   'began.',
#   'said',
#   'added',
#   'fumbled',
#   'repeated',
#   'said',
#   'said',
#   'spoke.',
#   'were',
#   'said',
#   'spoke,',
#   'asked.',
#   'went',
#   'added,',
#   'said.',
#   'certainly',
#   'went',
#   'did',
#   'said',
#   'found',
#   'now'],
#  'trotting': ['along', 'slowly'],
#  'hurry,': ['muttering'],
#  'muttering': ['to', 'to', 'over'],
#  'himself': ['as', 'suddenly:', 'upon', 'in'],
#  'came,': ['`Oh!', 'carried'],
#  '`Oh!': ['the', 'So'],
#  'Duchess,': ['the', '`and', '`chop', 'it', 'as', 'digging', 'who', '`as'],
#  'Duchess!': ['Oh!', 'The', 'Oh'],
#  'Oh!': ["won't"],
#  'savage': ['if', 'when', 'Queen:'],
#  'kept': ['her',
#   'fanning',
#   'her',
#   'on',
#   'all',
#   'getting',
#   'tossing',
#   'doubling',
#   'on',
#   'a',
#   'shifting',
#   'running',
#   'from'],
#  "waiting!'": ['Alice'],
#  'desperate': ['that'],
#  'ready': ['to', 'to', 'to', 'for', 'to', 'to', 'to'],
#  'help': ['of',
#   'to',
#   'me',
#   "it,'",
#   "that,'",
#   "it,'",
#   'bursting',
#   'thinking',
#   "it,'"],
#  'one;': ['so,', "Bill's"],
#  'so,': ['when', 'and', 'and', 'that', 'very', 'after', 'that'],
#  'began,': ['in', 'rather', 'in', 'in', '`for', 'in'],
#  'low,': ['timid', 'vulgar', 'and', 'hurried', 'weak', 'trembling'],
#  'timid': ['voice,', 'voice', 'and'],
#  'voice,': ['`If',
#   '`Let',
#   "(`That's",
#   '`Why',
#   'and',
#   'to',
#   'and,',
#   '`are',
#   'but',
#   '`--and',
#   '`Your',
#   '`What',
#   'the',
#   '`until',
#   'and'],
#  '`If': ['you',
#   'you',
#   'I',
#   'everybody',
#   "you're",
#   'it',
#   'you',
#   'you',
#   "I'd",
#   "that's",
#   'you',
#   'any',
#   "there's"],
#  'please,': ["sir--'", 'which', 'if'],
#  "sir--'": ['The'],
#  'violently,': ['dropped', 'that'],
#  'dropped': ['the', 'it', 'them,', 'his'],
#  'fan,': ['and'],
#  'skurried': ['away'],
#  'darkness': ['as'],
#  'hard': ['as', 'as', 'against', 'as', 'to', 'indeed', 'word,', 'at'],
#  'go.': ['Alice'],
#  'gloves,': ['and,', 'and', 'and'],
#  'and,': ['as',
#   'as',
#   "what's",
#   'when',
#   'as',
#   'as',
#   'as',
#   'after',
#   'last',
#   'turning',
#   'after',
#   'as',
#   'by',
#   'as',
#   'with',
#   'taking',
#   'just',
#   'after',
#   'by'],
#  'hall': ['was'],
#  'hot,': ['she'],
#  'fanning': ['herself'],
#  'talking:': ['`Dear,'],
#  '`Dear,': ['dear!'],
#  'queer': ['everything',
#   'thing,',
#   "to-day.'",
#   'it',
#   'to',
#   'things',
#   'indeed:--',
#   'little',
#   'noises,'],
#  'everything': ['is',
#   'is',
#   'upon',
#   'within',
#   'that',
#   'that',
#   "I've",
#   'about',
#   'there.'],
#  'to-day!': ['And'],
#  'yesterday': ['things', 'you'],
#  'usual.': ['I', '`Come,'],
#  'changed': ['in', 'for', 'for', 'his', 'since', 'several', 'into'],
#  'night?': ['Let'],
#  'think:': ['was'],
#  'morning?': ['I'],
#  'feeling': ['a', 'quite', 'very', 'at', 'very', 'very'],
#  'different.': ['But'],
#  'next': ['question',
#   'to',
#   'thing',
#   'moment',
#   'moment',
#   'that',
#   'thing',
#   'peeped',
#   'day,',
#   'the',
#   'walking',
#   'remark.',
#   "verse.'",
#   "verse,'",
#   'to',
#   "witness!'",
#   'witness',
#   "witness.'",
#   'witness.',
#   'witness'],
#  'question': ['is,', 'of', 'is,', 'the', 'is,', 'certainly', 'was'],
#  'Who': ['in', 'ever', 'for', 'cares', 'would', 'Stole'],
#  'am': ['I?',
#   'I',
#   'so',
#   'very',
#   'older',
#   'in',
#   'now?',
#   'I',
#   'I',
#   'I',
#   'I',
#   'I',
#   'to'],
#  'I?': ['Ah,'],
#  'Ah,': ["THAT'S"],
#  "THAT'S": ['the', 'all', 'a'],
#  ...}

# %%
def print_mimic(mimic_dict, word):
  # LAB(begin solution)
  for unused_i in range(200):
    print ('word, end=" "')
    nexts = mimic_dict.get(word)          # Returns None if not found
    if not nexts:
      nexts = mimic_dict['']  # Fallback to '' if not found
    word = random.choice(nexts)

# %%
print_mimic('alice.txt',"Alice's")
# Out:
# word, end=" "
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-38-39ddf2999fb0> in <module>
# ----> 1 print_mimic('alice.txt',"Alice's")
#
# <ipython-input-11-6ca22ab2575a> in print_mimic(mimic_dict, word)
#       3   for unused_i in range(200):
#       4     print ('word, end=" "')
# ----> 5     nexts = mimic_dict.get(word)          # Returns None if not found
#       6     if not nexts:
#       7       nexts = mimic_dict['']  # Fallback to '' if not found
#
# AttributeError: 'str' object has no attribute 'get'

# %%
def main():
  if len(sys.argv) != 2:
    print ('usage: ./mimic.py file-to-read')
    sys.exit(1)

  dict = mimic_dict(sys.argv[1])
  print_mimic(dict, '')

# %%
main()
# Out:
# usage: ./mimic.py file-to-read
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit: 1
